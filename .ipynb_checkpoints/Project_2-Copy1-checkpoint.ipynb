# %% [markdown]
# - Deletes unnecessary features
# - Slices 'Unknown' and 'Spring Training' out
# - Converts 'pitch_types_seq' and 'pitch_seq' to string
# - Adds columns:
#     - n-1 pitch_type_seq
#     - n-2 pitch_type_seq
#     - n-3 pitch_type_seq
#     - n-1 pitch_seq
#     - n-2 pitch_seq
#     - n-3 pitch_seq
# - For a given game_id, counts pitches cumulatively

# %%
import pandas as pd
import numpy as np

data=pd.read_csv('C:/Users/David/Documents/IPython_Notebooks/IntroDS/Term Project/pfx_parser/pitch_table.2014.csv'
                 , low_memory=False)

data.head(10)

# %%
#data=pd.read_csv('/Users/mkulunyar/Dropbox/DataScience_Project/PythonScraper/pitch_table.csv'
#                 , low_memory=False)

# %%
#Cleaning
#Deleting the features 
data_new=data.drop(['x', 'y', 'pfx_x', 'pfx_z', 'x0', 'y0', 'z0', 'vx0', 'vy0', 'vz0',
                  'ax', 'ay', 'az', 'zone', 'break_y', 'break_angle', 'break_length', 
                  'spin_dir', 'spin_rate'],1)

#Deleting 'Unknown' and 'Spring Training'
clean_pitch=data_new[(data_new['game_type_des']!='Unknown') & 
                     (data_new['game_type_des']!='Spring Training')]

clean_pitch=clean_pitch.reset_index().drop(['index'],1)

# %%
clean_pitch['pitch_type_seq']=clean_pitch.pitch_type_seq.astype(str)

# %%
clean_pitch['pitch_seq']=clean_pitch.pitch_seq.astype(str)

# %%
len(clean_pitch)
# Out:
# 2169466

# %%
#Pitch Type Sequence
#n-1
q=[]
for i in range(len(clean_pitch)):
    if len(clean_pitch['pitch_type_seq'][i])>2:
        q.append(clean_pitch['pitch_type_seq'][i][-5:-3])
    else:
        q.append('NaN')

#n-2
w=[]
for i in range(len(clean_pitch)):
    if len(clean_pitch['pitch_type_seq'][i])>5:
        w.append(clean_pitch['pitch_type_seq'][i][-8:-6])
    else:
        w.append('NaN')


#n-3
e=[]
for i in range(len(clean_pitch)):
    if len(clean_pitch['pitch_type_seq'][i])>8:
        e.append(clean_pitch['pitch_type_seq'][i][-11:-9])
    else:
        e.append('NaN')

# %%
#Pitch Sequence
#n-1
a=[]
for i in range(len(clean_pitch)):
    if len(clean_pitch['pitch_seq'][i])>1:
        a.append(clean_pitch['pitch_seq'][i][-2:-1])
    else:
        a.append('NaN')

#n-2
s=[]
for i in range(len(clean_pitch)):
    if len(clean_pitch['pitch_seq'][i])>2:
        s.append(clean_pitch['pitch_seq'][i][-3:-2])
    else:
        s.append('NaN')


#n-3
d=[]
for i in range(len(clean_pitch)):
    if len(clean_pitch['pitch_seq'][i])>3:
        d.append(clean_pitch['pitch_seq'][i][-4:-3])
    else:
        d.append('NaN')

# %%
clean_pitch['n-1_pitch_type']=q

# %%
clean_pitch['n-2_pitch_type']=w

# %%
clean_pitch['n-2_pitch_type']=e

# %%
clean_pitch['n-1_pitch']=a

# %%
clean_pitch['n-2_pitch']=s

# %%
clean_pitch['n-3_pitch']=d

# %%
clean_pitch[['pitch_seq','n-1_pitch','n-2_pitch','n-3_pitch']]
# Out:
#         pitch_seq n-1_pitch n-2_pitch n-3_pitch
# 0               S       NaN       NaN       NaN
# 1              SX         S       NaN       NaN
# 2               S       NaN       NaN       NaN
# 3              SC         S       NaN       NaN
# 4             SCF         C         S       NaN
# 5            SCFX         F         C         S
# 6               C       NaN       NaN       NaN
# 7              CF         C       NaN       NaN
# 8             CFS         F         C       NaN
# 9               X       NaN       NaN       NaN
# 10              B       NaN       NaN       NaN
# 11             BC         B       NaN       NaN
# 12            BCX         C         B       NaN
# 13              B       NaN       NaN       NaN
# 14             BX         B       NaN       NaN
# 15              X       NaN       NaN       NaN
# 16              B       NaN       NaN       NaN
# 17             BX         B       NaN       NaN
# 18              C       NaN       NaN       NaN
# 19             CB         C       NaN       NaN
# 20            CBB         B         C       NaN
# 21           CBBB         B         B         C
# 22          CBBBC         B         B         B
# 23         CBBBCB         C         B         B
# 24              S       NaN       NaN       NaN
# 25             SB         S       NaN       NaN
# 26            SBX         B         S       NaN
# 27              B       NaN       NaN       NaN
# 28             BB         B       NaN       NaN
# 29            BBC         B         B       NaN
# ...           ...       ...       ...       ...
# 2169436         B       NaN       NaN       NaN
# 2169437        BB         B       NaN       NaN
# 2169438       BBB         B         B       NaN
# 2169439      BBBC         B         B         B
# 2169440     BBBCB         C         B         B
# 2169441         B       NaN       NaN       NaN
# 2169442        BB         B       NaN       NaN
# 2169443       BBC         B         B       NaN
# 2169444      BBCF         C         B         B
# 2169445     BBCFS         F         C         B
# 2169446    BBCFSF         S         F         C
# 2169447   BBCFSFF         F         S         F
# 2169448  BBCFSFFX         F         F         S
# 2169449         C       NaN       NaN       NaN
# 2169450        CB         C       NaN       NaN
# 2169451       CBB         B         C       NaN
# 2169452      CBBB         B         B         C
# 2169453     CBBBS         B         B         B
# 2169454    CBBBSS         S         B         B
# 2169455         B       NaN       NaN       NaN
# 2169456        BB         B       NaN       NaN
# 2169457       BBX         B         B       NaN
# 2169458         C       NaN       NaN       NaN
# 2169459        CB         C       NaN       NaN
# 2169460       CBB         B         C       NaN
# 2169461      CBBB         B         B         C
# 2169462     CBBBC         B         B         B
# 2169463    CBBBCX         C         B         B
# 2169464         C       NaN       NaN       NaN
# 2169465        CB         C       NaN       NaN
#
# [2169466 rows x 4 columns]

# %%
#Pitchers Cumulative Pitches per Game
clean_pitch['pit_id']=clean_pitch.pit_id.astype(int)
clean_pitch['game_id']=clean_pitch.game_id.astype(int)
clean_pitch['cum_pitch_count']=clean_pitch.groupby(['game_id','pit_id']).cumcount()+1
clean_pitch[['game_id', 'pit_id','cum_pitch_count']].head()
# Out:
#    game_id  pit_id  cum_pitch_count
# 0   449268  622663                1
# 1   449268  622663                2
# 2   449268  622663                3
# 3   449268  622663                4
# 4   449268  622663                5
